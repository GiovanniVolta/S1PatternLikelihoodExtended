# %%
# %run '/home/gvolta/Desktop/Function/Useful/Def.ipynb'
# Out:
# Initialization done, Notebook was last run on: 19/06/2019

# %%
import lax 
from lax.lichens import sciencerun1
from lax.lichens import sciencerun0
from lax.lichens import postsr1

# %%
from pax import units, configuration
pax_config = configuration.load_configuration('XENON1T')['DEFAULT']
tpc_height = pax_config['tpc_length']
tpc_radius = pax_config['tpc_radius']

import hax
hax.init(experiment='XENON1T',
         pax_version_policy = 'v6.10.1',
         main_data_paths= ['/dali/lgrandi/xenon1t/processed/pax_v6.10.1'], 
         minitree_paths = ['/dali/lgrandi/giovo/minitrees/pax_v6.10.1',
                           '/dali/lgrandi/xenon1t/minitrees/pax_v6.10.1'],
         make_minitrees = False)

# %matplotlib inline

# %% [markdown]
# - Rn_cut_SR1_S1PL.haxcache -> Rn_cut_1_DAQFlash_SR1_S1PL.pkl
# - Rn_test_SR1_S1PL.haxcache -> Rn_cut_2_DAQFlash_SR1_S1PL.pkl
# - Rn_rest_SR1_S1PL.haxcache -> Rn_cut_3_DAQFlash_SR1_S1PL.pkl

# %%
file1 = '/dali/lgrandi/giovo/pickle/pax_v6.10.1/Rn_cut_1_DAQFlash_SR1_S1PL.pkl'
data1 = pd.read_pickle(file1)

file2 = '/dali/lgrandi/giovo/pickle/pax_v6.10.1/Rn_cut_2_DAQFlash_SR1_S1PL.pkl'
data2 = pd.read_pickle(file2)

#file3 = '/dali/lgrandi/giovo/pickle/pax_v6.10.1/Rn_cut_3_DAQFlash_SR1_S1PL.pkl'
#data3 = pd.read_pickle(file3)

#data = data3
data = [data1, data2]
data = pd.concat(data, ignore_index=True)
del data1, data2

# %% [markdown]
# ## Data

# %% [raw]
# for i in range(len(data.columns)): print(data.columns[i])

# %% [markdown]
# CES calculated with z-dependent: https://xe1t-wiki.lngs.infn.it/doku.php?id=xenon:xenon1t:g1g2resfordec#energy_calibration_with_z-dependence_using_the_doke_method
# - g1 = (0.1432 +/- 0.0004) + (0.000049 +/- 0.000007)*z
# - g2 = (11.63 +/- 0.10) + (0.009 +/- 0.002)*z

# %%
W = 13.7 #eV
g1 = 0.1432 + 0.000049*data['z_3d_nn_tf']
g2 = 11.63  + 0.009*data['z_3d_nn_tf']

data['CES'] = W*((data['cs1_nn_tf']/g1) + (data['cs2_bottom_nn_tf']/g2) )
data_white = data.copy()

# %%
data_distribution(data_white, 'x_3d_nn_tf', 'y_3d_nn_tf', 'z_3d_nn_tf', 'r_3d_nn_tf', bins=[100,100])
# Out:
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/matplotlib/colors.py:927: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
plt.figure(figsize=(12,8))
plt.hist(data_white['CES']/10**6, bins = (10000), 
         range=(0, 12), 
         histtype='step')
plt.xlabel('Energy [MeV]')
plt.ylabel('N')
plt.yscale('log')

plt.tight_layout()
plt.show()

# %% [raw]
# plt.plot(data['cs1_nn_tf'], np.log10(data['cs2_nn_tf']/data['cs1_nn_tf']),
#          linestyle=' ', linewidth=1, marker='o',ms=1, color='purple')
# plt.xlabel('cs1 [PE]')
# plt.ylabel('log10(cs2/cs1)')
#
# plt.tight_layout()
# plt.show()

# %% [raw]
# plt.hist2d(data['cs1_nn_tf'], data['cs2_bottom_nn_tf']/100, bins = (200, 200),
#            range=((0,120000), (0,60000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(), cmin = 1,alpha = 1)
# plt.colorbar(label='Number of events')
# plt.xlabel('cs1_nn_tf [PE]')
# plt.ylabel('cs2_nn_tf [PE]/100')
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Selection

# %% [markdown]
# - Z in [-83.45, -13.45] cm and r < 39.85 cm for fiducialization
# - s1_pattern_fit =! NaN
# - S2 =! NaN
# - CS2AFT_Extended
# - CutS2Threshold
# - CutInteractionsPeaksBiggest

# %%
CS2AFT_Extended = postsr1.CS2AreaFractionTopExtended()
CutS2Threshold = sciencerun1.S2Threshold()
CutInteractionsPeaksBiggest = sciencerun1.InteractionPeaksBiggest()
CutS2Width = sciencerun1.S2Width()

# %%
data['CutFiducialization'] = (data['z_3d_nn_tf'] < -13.45)&(data['z_3d_nn_tf'] > -83.45)&(data['r_3d_nn_tf'] < 39.85)
data['CutS1PatternFitExist'] = np.isnan(data['s1_pattern_fit'])
data['CutCS2bExist'] = np.isnan(data['cs2_bottom_nn_tf'])

# %%
data = CS2AFT_Extended.process(data)
data = CutS2Threshold.process(data)
data = CutInteractionsPeaksBiggest.process(data)

# %%
data.columns
# Out:
# Index(['alt_s1_interaction_drift_time', 'alt_s1_interaction_z',
#        'alt_s1_tight_coincidence', 'alt_s2_interaction_s2_range_50p_area',
#        'alt_s2_interaction_s2_range_80p_area', 'alt_s2_interaction_x',
#        'alt_s2_interaction_y', 'alt_s2_interaction_z', 'cs1', 'cs1_nn',
#        ...
#        'CutHEVCheck', 'CES', 'CutFiducialization', 'CutS1PatternFitExist',
#        'CutCS2bExist', 'cxys2', 'cs2_aft', 'CutCS2AreaFractionTopExtended',
#        'CutS2Threshold', 'CutInteractionPeaksBiggest'],
#       dtype='object', length=172)

# %%
data = hax.cuts.selection(data, data['CutFiducialization'] == True)
data = hax.cuts.selection(data, data['CutS1PatternFitExist'] == False)
data = hax.cuts.selection(data, data['CutCS2bExist'] == False)
data = hax.cuts.selection(data, data['CutCS2AreaFractionTopExtended'] == True)
data = hax.cuts.selection(data, data['CutS2Threshold'] == True)
data = hax.cuts.selection(data, data['CutInteractionPeaksBiggest'] == True)
# Out:
# Unnamed selection: 10423399 rows removed (15.88% passed)
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/hax-2.5.0-py3.4.egg/hax/cuts.py:130: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   d.cut_history = prev_cuts + [passthrough_dict]
# Unnamed selection: 0 rows removed (100.00% passed)
# Unnamed selection: 0 rows removed (100.00% passed)
# Unnamed selection: 60417 rows removed (96.93% passed)
# Unnamed selection: 100742 rows removed (94.72% passed)
# Unnamed selection: 71428 rows removed (96.05% passed)

# %%
data = CutS2Width.process(data)
data = hax.cuts.selection(data, data['CutS2Width'] == True)
# Out:
# Unnamed selection: 187872 rows removed (89.17% passed)
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/hax-2.5.0-py3.4.egg/hax/cuts.py:130: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   d.cut_history = prev_cuts + [passthrough_dict]

# %%
#data.to_pickle('/dali/lgrandi/giovo/pickle/pax_v6.10.1/Rn_cutted_1_2_S2W_SR1_S1PL.pkl')

# %%
data_distribution(data, 'x_3d_nn_tf', 'y_3d_nn_tf', 'z_3d_nn_tf', 'r_3d_nn_tf', bins=[100,100])
# Out:
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/matplotlib/colors.py:927: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
plt.figure(figsize=(12,8))
plt.hist(data['CES']/10**6, bins = (10000), 
         range=(0, 12), 
         histtype='step')
plt.xlabel('Energy [MeV]')
plt.ylabel('N')
plt.yscale('log')

plt.tight_layout()
plt.show()

# %% [raw]
# plt.figure(figsize=(20,20))
# plt.subplot(311)
# plt.hist(data['CES']/10**6, bins = (2000),
#          range=(0, 20),
#          histtype='stepfilled', alpha=0.3, color='purple')
# plt.xlabel('Energy [MeV]')
# plt.ylabel('N')
# plt.yscale('log')
#
# plt.subplot(312)
# plt.hist2d(data['cs1_nn_tf'], data['cs2_bottom_nn_tf']/100, bins = (200, 200),
#            range=((0,120000), (0,60000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(), cmin = 1,alpha = 1)
# plt.colorbar(label='Number of events')
# plt.xlabel('cs1_nn_tf [PE]')
# plt.ylabel('cs2_nn_tf [PE]/100')
#
# plt.subplot(313)
# plt.plot(data['cs1_nn_tf'], np.log10(data['cs2_nn_tf']/data['cs1_nn_tf']),
#          linestyle=' ', linewidth=1, marker='o',ms=1, color='purple')
# plt.xlabel('cs1 [PE]')
# plt.ylabel('log10(cs2/cs1)')
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Distribution in the (S1, S1 pattern fit) phase space after pre-selection

# %% [raw]
# plt.figure(figsize=(18,6))
# plt.subplot(131)
# plt.hist2d(data['s1'], data['s1_pattern_fit'], bins = (1000, 400),
#            range=((0,3000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')
#
# plt.subplot(132)
# plt.hist2d(data['s1'], data['s1_pattern_fit'], bins = (1000, 400),
#            range=((3000,30000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')
#
# plt.subplot(133)
# plt.hist2d(data['s1'], data['s1_pattern_fit'], bins = (1000, 400),
#            range=((30000,150000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')

# %% [markdown]
# ## S2 Single Scatter Cut HE
# - (largest_other_s2>0) & (s2>0) & (largest_other_s2_pattern_fit>0) & ((largest_other_s2_delay_main_s1>6e3)|(largest_other_s2_delay_main_s1<0))

# %%
data_S2singleScatterHE = data.copy()
# Tianyu new S2Singlescatter cut
import pickle
with open('/project2/lgrandi/zhut/s2_single_classifier_gmix_v6.10.0.pkl', 'rb') as f:
    gmix=pickle.load(f)

def classify(df):
    df['CutS2SingleScatterHE'] = 0

    mask = df.eval('(largest_other_s2>0) & (s2>0) & (largest_other_s2_pattern_fit>0) \
    ')
    Y = np.concatenate([np.log10(df.loc[mask,['largest_other_s2', 'largest_other_s2_pattern_fit', 's2']]),
                    ],
                   axis=1)
    df.loc[mask,'CutS2SingleScatterHE'] = gmix.predict(Y)
    df.loc[:, 'CutS2SingleScatterHE'] = np.array(df.CutS2SingleScatterHE, bool)
    return df

data_S2singleScatterHE = classify(data_S2singleScatterHE)

# %%
data_S2singleScatterHE = hax.cuts.selection(data_S2singleScatterHE, data_S2singleScatterHE['CutS2SingleScatterHE'] == True)
# Out:
# Unnamed selection: 488429 rows removed (68.42% passed)
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/hax-2.5.0-py3.4.egg/hax/cuts.py:130: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   d.cut_history = prev_cuts + [passthrough_dict]

# %%
data_S2singleScatterHE = CutS2Width.process(data_S2singleScatterHE)
data_S2singleScatterHE = hax.cuts.selection(data_S2singleScatterHE, data_S2singleScatterHE['CutS2Width'] == True)
# Out:
# Unnamed selection: 0 rows removed (100.00% passed)
# /project/lgrandi/anaconda3/envs/pax_head/lib/python3.4/site-packages/hax-2.5.0-py3.4.egg/hax/cuts.py:130: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   d.cut_history = prev_cuts + [passthrough_dict]

# %%
#data_S2singleScatterHE.to_pickle('/dali/lgrandi/giovo/pickle/pax_v6.10.1/Rn_cutted_1_2_S2W_S2SS_SR1_S1PL.pkl')

# %% [raw]
# plt.figure(figsize=(18,6))
# plt.subplot(131)
# plt.hist2d(data_S2singleScatterHE['cs1_nn_tf'], data_S2singleScatterHE['s1_pattern_fit'], bins = (1000, 400),
#            range=((0,3000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')
#
# plt.subplot(132)
# plt.hist2d(data_S2singleScatterHE['cs1_nn_tf'], data_S2singleScatterHE['s1_pattern_fit'], bins = (1000, 400),
#            range=((3000,30000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')
#
# plt.subplot(133)
# plt.hist2d(data_S2singleScatterHE['cs1_nn_tf'], data_S2singleScatterHE['s1_pattern_fit'], bins = (1000, 400),
#            range=((30000,150000), (0,3000)),
#            cmap=plt.cm.plasma, norm=matplotlib.colors.LogNorm(),
#            cmin = 1,alpha = 1)
# #plt.colorbar(label='Number of events')
# plt.xlabel('s1 [PE]')
# plt.ylabel('s1_pattern_fit')
